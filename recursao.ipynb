# %% [markdown]
# [![Open in Visual Studio Code](https://classroom.github.com/assets/open-in-vscode-2e0aaae1b6195c2367325f4f02e2d04e9abb55f0b24a779b69b11b9e10269abc.svg)](https://classroom.github.com/online_ide?assignment_repo_id=22978564&assignment_repo_type=AssignmentRepo)
# # Exercício de Re-aquecimento - Recursão
#
# Vamos fazer alguns exercícios de programação, para re-lembrar algortimos recursivos. Além disto, é uma oportunidade para utilizarmos
# nosso ambiente de trabalho (Git-Github-Github classroom).
#
#
# 1. Desenvolva algoritmos recursivos para os seguintes problemas e implemente-os (em Java, por exemplo):
#    1. Multiplicação de dois números naturais, através de somas sucessivas (Ex.: 6 ∗ 4 = 4 + 4 + 4 + 4 + 4 + 4).
#    1. Soma de dois números naturais, através de incrementos sucessivos (Ex.: 3 + 2 = + + (+ + + 1)).
#    1. Cálculo de 1 + 1/2 + 1/3 + 1/4 + ... + 1/N.
#    1. Inversão de uma string.
#    1. Gerador da sequência dada por:
#          * F(1) = 1
#          * F(2) = 2
#          * F(n) = 2 ∗ F(n − 1) + 3 ∗ F(n − 2).
#    1.  Gerador de Sequência de Ackerman:
#          * A(m, n) = n + 1, se m = 0
#          * A(m, n) = A(m − 1, 1), se m != 0 e n = 0
#          * A(m, n) = A(m − 1, A(m, n − 1)), se m != 0 e n != 0.
#    1. A partir de um vetor de números inteiros, calcule a soma e o produto dos elementos
# do vetor.
#    1. Verifique se uma palavra é palíndromo (Ex. aba, abcba, xyzzyx).
#    1. Dado um número n, gere todas as possíveis combinações com as n primeiras letras
# do alfabeto. Ex.: n = 3. Resposta: ABC, ACB, BAC, BCA, CAB, CBA.
#    1. Defina uma sequência de Fibonacci generalizada, de f0 a f1 como sequência
# fibg(f0, f1, 0), fibg(f0, f1, 1), fibg(f0, f1, 2), ..., onde:
#          * fibg(f0, f1, 0) = f0
#          * fibg(f0, f1, 1) = f1
#          * fibg(f0, f1, n) = fibg(f0, f1, n − 1) + fibg(f0, f1, n − 2), se n > 1.

# %%
#1
def mult_recursiva(a,b):
    if a == 0:
        return 0
    else:
        print(f"mult_recursiva({a-1}, {b})")
        return b + mult_recursiva(a-1, b)

a=6
b=4

resultado = mult_recursiva(a,b)
print(f"resultado final: {resultado}")
# Out:
# mult_recursiva(5, 4)
# mult_recursiva(4, 4)
# mult_recursiva(3, 4)
# mult_recursiva(2, 4)
# mult_recursiva(1, 4)
# mult_recursiva(0, 4)
# resultado final: 24

# %%
#2

def soma_recursiva(a,b):
    print(f"soma_recursiva({a}, {b})")
    if a == 0 and b == 0:
        return 0
    elif a == 0:
        return soma_recursiva(a, b-1) + 1
    else:
        return soma_recursiva(a-1, b) + 1

a=3
b=2

resultado = soma_recursiva(a,b)
print(f"resultado final: {resultado}")
# Out:
# soma_recursiva(3, 2)
# soma_recursiva(2, 2)
# soma_recursiva(1, 2)
# soma_recursiva(0, 2)
# soma_recursiva(0, 1)
# soma_recursiva(0, 0)
# resultado final: 5

# %%
#3.

def div_recursiva(n):
    if n==1:
        return 1
    else:
        print(f"div_recursiva({n-1})")
        return (1/n) + div_recursiva(n-1)

n = 6
resultado = div_recursiva(n)
print(f"resultado final: {resultado:2f}")

prova_real = 1/6 + 1/5 + 1/4 + 1/3 + 1/2 + 1
print(f"prova real: {prova_real:2f}")
# Out:
# div_recursiva(5)
# div_recursiva(4)
# div_recursiva(3)
# div_recursiva(2)
# div_recursiva(1)
# resultado final: 2.450000
# prova real: 2.450000

# %%
# 4.

def inverte_string(s):
    if s == "":
        return ""
    else:
        print(f"inverte_string('{s[:-1]}')")
        return s[-1] + inverte_string(s[:-1])

s = "pucrs"

resultado = inverte_string(s)
print(f"resultado final: '{resultado}'")
# Out:
# inverte_string('pucr')
# inverte_string('puc')
# inverte_string('pu')
# inverte_string('p')
# inverte_string('')
# resultado final: 'srcup'

# %%
#5.

# Gerador da sequência dada por:
#          * F(1) = 1
#          * F(2) = 2
#          * F(n) = 2 ∗ F(n − 1) + 3 ∗ F(n − 2).

def F(n):
    if n == 1:
        return 1
    elif n == 2:
        return 2
    else:
        print(f"F({n-1}) e F({n-2})")
        return 2 * F(n-1) + 3 * F(n-2)

n = 5
resultado = F(n)
print(f"resultado final: {resultado}")
# Out:
# F(4) e F(3)
# F(3) e F(2)
# F(2) e F(1)
# F(2) e F(1)
# resultado final: 61
